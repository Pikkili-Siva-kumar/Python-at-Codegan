# %%
a = int(input())
b = int(input())
print(a+b)
# Out:
#  12
#  14
# 26

# %%
num1 = int(input())
num2 = int(input())
print("quitient", num1 // b)
print("Remainder", num1 % num2)
# Out:
#  30
#  90
# quitient 2
# Remainder 30

# %%
a = int(input())
if a % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
#  24
# Even

# %%
a = int(input())
b = int(input())
a = a+b
b = a-b
a = a-b
print(a,b)
# Out:
#  2
#  4
# 4 2

# %%
a = int(input())
b = int(input())
c = int(input())
if a >b and a > c:
    print(a)
elif b > c:
    print(b)
else:
    print(c)
# Out:
#  2
#  5
#  20
# 20

# %%
n = int(input())
print(n**2)
# Out:
#  5
# 25

# %%
a = int(input())
b = int(input())
if a % 2 ==0:
    print("Divisible Number:")
else:
    print("NOt Divisible Number:")
# Out:
#  2
#  4
# Divisible Number:

# %%
s1 = int(input())
s2 = int(input())
print(s1*s2)
# Out:
#  2
#  10
# 20

# %%
s = int(input())
if s > 0:
    print("Pasitive")
elif s < 0:
    print("Negative")
else:
    print("Zero")
# Out:
#  -1
# Negative

# %%
l1 = int(input())
l2 = int(input())
if l1 == l2:
    print("Equal Equal")
else:
    print("Not Equal")
# Out:
#  3
#  5
# Not Equal

# %%
n = int(input())
if n % 3 == 0 and n % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
#  15
# Yes

# %%
a = int(input())
b = int(input())
c = int(input())
if a > b:
    if a < c:
        print(a)
    else:
        print(c)
else:
    if b > c:
        print(b)
    else:
        print(c)
# Out:
#  2
#  6
#  10
# 10

# %%
year = int(input())
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap year")
else:
    print("Not Leap year")
# Out:
#  2000
# Leap year

# %%
m = int(input())
if m >= 90 and m < 100:
    print('A')
elif m >= 75 and m < 89:
    print('B')
elif m >= 50 and m < 74:
    print('C')
else:
    print("Fails")
# Out:
#  82
# B

# %%
units = int(input())
if units <= 100:
    bill = units * 5
elif units <= 200:
    bill = units * 7
else:
    bill = units * 10
    print("units =", bill)
# Out:
#  201
# units = 2010
